# %%
import gdown

output = "fandom_wiki_articles.zip"
file_id = '1DzYpGhXKLy9mq5gaupnYtIrnIC3uqMep'

gdown.download('https://drive.google.com/uc?id='+file_id, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DzYpGhXKLy9mq5gaupnYtIrnIC3uqMep
# To: /content/articles.zip
# 100%|██████████| 10.8M/10.8M [00:01<00:00, 8.09MB/s]
# 'articles.zip'

# %%
# !jar xvf ./articles.zip
# Out:
#   created: articles/
#  inflated: articles/Ivo_Kristof.txt
#  inflated: articles/Shagga.txt
#  inflated: articles/Greyguard.txt
#  inflated: articles/Whore.txt
#  inflated: articles/Helen_Sadler.txt
#  inflated: articles/Stark_guard_1_(A_Man_Without_Honor).txt
#  inflated: articles/Robert_Hladik.txt
#  inflated: articles/Eddard_and_Catelyn_Stark.txt
#  inflated: articles/Forrester-Whitehill_conflict.txt
#  inflated: articles/House_Greyjoy_(Histories_%26_Lore).txt
#  inflated: articles/Ruth_Jenkins.txt
#  inflated: articles/Meraxes.txt
#  inflated: articles/Symon_Hollard.txt
#  inflated: articles/Carice_van_Houten.txt
#  inflated: articles/House_Tarbeck.txt
#  inflated: articles/Jack_Olohan.txt
#  inflated: articles/Liang_Yang.txt
#  inflated: articles/Knight_of_the_Gate.txt
#  inflated: articles/The_Stormlands.txt
#  inflated: articles/The_Kingsmoot.txt
#  inflated: articles/Derwa_Frey.txt
#  inflated: articles/Nick_Boulton.txt
#  inflated: articles/Sheila_Atim.txt
#  inflated: articles/Northern_Allegiances_to_House_Stark.txt
#  inflated: articles/Dagmer.txt
#  inflated: articles/Imry_Florent.txt
#  inflated: articles/Luke_Gomes.txt
#  inflated: articles/Daena_Targaryen.txt
#  inflated: articles/Forum:Help_desk.txt
#  inflated: articles/Littlefinger%27s_brothel.txt
#  inflated: articles/The_Seven.txt
#  inflated: articles/Tion_Tarbeck.txt
#  inflated: articles/Gorne.txt
#  inflated: articles/House_Reed_(Histories_%26_Lore).txt
#  inflated: articles/Jason_Mallister.txt
#  inflated: articles/Lowell.txt
#  inflated: articles/Richard_Madden.txt
#  inflated: articles/Aegon_III_Targaryen.txt
#  inflated: articles/Dan_Miskimmon.txt
#  inflated: articles/Rhodri_Miles.txt
#  inflated: articles/Martha_Mackintosh.txt
#  inflated: articles/Niall_Bishop.txt
#  inflated: articles/Quicksilver.txt
#  inflated: articles/Tim_Halloran.txt
#  inflated: articles/Michael_Patrick.txt
#  inflated: articles/Ironborn_invasion_of_the_North.txt
#  inflated: articles/Merry_Frey.txt
#  inflated: articles/Black_Friday.txt
#  inflated: articles/Amie_Stephenson.txt
#  inflated: articles/Game_of_Thrones:_Music_from_the_HBO_Series_-_Season_6.txt
#  inflated: articles/James_Tolcher.txt
#  inflated: articles/Lhara.txt
#  inflated: articles/The_Kingsroad.txt
#  inflated: articles/House_Bolton.txt
#  inflated: articles/Weeping_Lady.txt
#  inflated: articles/Book_of_the_Stranger.txt
#  inflated: articles/House_Hastwyck.txt
#  inflated: articles/Serving_girl.txt
#  inflated: articles/Lormelle_Long_Lance.txt
#  inflated: articles/Ewan_Mitchell.txt
#  inflated: articles/Battle_of_Fair_Isle.txt
#  inflated: articles/Ian_van_Temperley.txt
#  inflated: articles/Serac_Baratheon.txt
#  inflated: articles/Street_of_Looms.txt
#  inflated: articles/Warg.txt
#  inflated: articles/The_Ice_Dragon.txt
#  inflated: articles/Good_Masters.txt
#  inflated: articles/Jhogo.txt
#  inflated: articles/New_Ghis.txt
#  inflated: articles/Croft.txt
#  inflated: articles/White_Walker_ice_blade.txt
#  inflated: articles/Starfall.txt
#  inflated: articles/Derrock.txt
#  inflated: articles/Argilac_Durrandon.txt
#  inflated: articles/Ragman_Lane.txt
#  inflated: articles/Vladim%C3%ADr_Furd%C3%ADk.txt
#  inflated: articles/Jonos_Bracken.txt
#  inflated: articles/Fury.txt
#  inflated: articles/Edric_Baratheon.txt
#  inflated: articles/Gyula_Toth.txt
#  inflated: articles/Game_of_Thrones:_Music_from_the_HBO_Series.txt
#  inflated: articles/Drowned_Men.txt
#  inflated: articles/Lord_Commander.txt
#  inflated: articles/Dean_S._Jagger.txt
#  inflated: articles/The_Queen%27s_Justice.txt
#  inflated: articles/North_of_the_Wall.txt
#  inflated: articles/Bill_Davey.txt
#  inflated: articles/Vinnie_McCabe.txt
#  inflated: articles/Smitty.txt
#  inflated: articles/Jamie_Edgell.txt
#  inflated: articles/Oberyn_Martell.txt
#  inflated: articles/Scott_Hillier.txt
#  inflated: articles/Lannister_Captain_(Home).txt
#  inflated: articles/Attainder.txt
#  inflated: articles/Petra_Tallhart.txt
#  inflated: articles/Freddie_Mason.txt
#  inflated: articles/The_Seven-Pointed_Star.txt
#  inflated: articles/Jesse_Morris.txt
#  inflated: articles/Kristina_Krepela.txt
#  inflated: articles/King%27s_Landing_boaster.txt
#  inflated: articles/Robbie_Keane.txt
#  inflated: articles/Cripples,_Bastards,_and_Broken_Things.txt
#  inflated: articles/Redwyne_Fleet.txt
#  inflated: articles/Samyrian.txt
#  inflated: articles/Maria_Sikavica.txt
#  inflated: articles/Tortured_slave.txt
#  inflated: articles/The_Bear_and_the_Maiden_Fair_(episode).txt
#  inflated: articles/Evenfall_Hall.txt
#  inflated: articles/Rachel_Puchkoff.txt
#  inflated: articles/Arrowhead_mountain.txt
#  inflated: articles/Shade_of_the_evening.txt
#  inflated: articles/Oona_Chaplin.txt
#  inflated: articles/Shrykos.txt
#  inflated: articles/King_in_the_north.txt
#  inflated: articles/Eastwatch-by-the-Sea.txt
#  inflated: articles/Tanda_Stokeworth.txt
#  inflated: articles/Garrison_Fowler.txt
#  inflated: articles/Lord_of_the_Arbor.txt
#  inflated: articles/Jonathan_McBride.txt
#  inflated: articles/Sibel_Kekilli.txt
#  inflated: articles/Steve_Love.txt
#  inflated: articles/House_Dondarrion.txt
#  inflated: articles/Edward_Dogliani.txt
#  inflated: articles/Jaqen_H%27ghar.txt
#  inflated: articles/Summer.txt
#  inflated: articles/King_of_the_Andals,_the_Rhoynar,_and_the_First_Men.txt
#  inflated: articles/White_Walker_2_(Winter_is_Coming).txt
#  inflated: articles/Lord_of_Deepwood_Motte.txt
#  inflated: articles/Susan_Brown.txt
#  inflated: articles/Queensgate.txt
#  inflated: articles/Mummer_3.txt
#  inflated: articles/Aaron_Blackman.txt
#  inflated: articles/Eva_Butterly.txt
#  inflated: articles/Dwarf_2.txt
#  inflated: articles/Kurleket.txt
#  inflated: articles/Forrester_greatsword.txt
#  inflated: articles/Wickenden.txt
#  inflated: articles/Bert.txt
#  inflated: articles/Winterfell_(Histories_%26_Lore).txt
#  inflated: articles/Lord_of_Dragonstone.txt
#  inflated: articles/Rodeo_FX.txt
#  inflated: articles/Sand_Snakes.txt
#  inflated: articles/Mag_Nuk.txt
#  inflated: articles/Exile.txt
#  inflated: articles/Doug_Seus.txt
#  inflated: articles/Diogo_Sales.txt
#  inflated: articles/Three_Sisters.txt
#  inflated: articles/Hadi_Kermani.txt
#  inflated: articles/Emilio_Doorgasingh.txt
#  inflated: articles/Greenseer.txt
#  inflated: articles/Ivailo_Dimitrov.txt
#  inflated: articles/Sarnori.txt
#  inflated: articles/Aerys_Targaryen.txt
#  inflated: articles/Tregar_Ormollen.txt
#  inflated: articles/Minisa_Tully.txt
#  inflated: articles/Kinga_Gavalda_Kosa.txt
#  inflated: articles/Water_Gardens.txt
#  inflated: articles/Darlessa_Marbrand.txt
#  inflated: articles/Moonsingers.txt
#  inflated: articles/Jane_Goldman.txt
#  inflated: articles/The_Defiance_of_Duskendale.txt
#  inflated: articles/Genna_Lannister.txt
#  inflated: articles/It%27s_Always_Summer_Under_the_Sea.txt
#  inflated: articles/Matt_McArdle.txt
#  inflated: articles/Port_of_Ibben.txt
#  inflated: articles/Poison.txt
#  inflated: articles/Lothar_Frey.txt
#  inflated: articles/Temple_of_the_dosh_khaleen.txt
#  inflated: articles/King%27s_Landing.txt
#  inflated: articles/Peter_Vaughan.txt
#  inflated: articles/Lord_of_Last_Hearth.txt
#  inflated: articles/Musician_2_(The_Lion_and_the_Rose).txt
#  inflated: articles/John_Macmillan.txt
#  inflated: articles/Naomi_Ackie.txt
#  inflated: articles/Prisoner.txt
#  inflated: articles/Martin_Pemberton.txt
#  inflated: articles/Noah_Taylor.txt
#  inflated: articles/Dragonlords.txt
#  inflated: articles/Fenix_Searle.txt
#  inflated: articles/The_Dragon_and_the_Wolf.txt
#  inflated: articles/Walder_Frey.txt
#  inflated: articles/Neil_Keery.txt
#  inflated: articles/Lara_Pulver.txt
#  inflated: articles/Vencislav_Zlatkov_Stoyanov.txt
#  inflated: articles/The_Broken_Man.txt
#  inflated: articles/Lois_Winstone.txt
#  inflated: articles/Honeywine.txt
#  inflated: articles/Alchemists_Guild.txt
#  inflated: articles/Dorian_Hightower%27s_first_wife.txt
#  inflated: articles/House_Estermont.txt
#  inflated: articles/Ben_Dimmock.txt
#  inflated: articles/Will_Simpson.txt
#  inflated: articles/Lannister_bannerman.txt
#  inflated: articles/Weyland.txt
#  inflated: articles/Mysaria.txt
#  inflated: articles/Fiach_Kunz.txt
#  inflated: articles/Arran_Topham.txt
#  inflated: articles/Cheese.txt
#  inflated: articles/Game_of_Thrones_Season_2.txt
#  inflated: articles/David_Bradley.txt
#  inflated: articles/Andrei_Claude.txt
#  inflated: articles/Helos_Blackbrow.txt
#  inflated: articles/Biter.txt
#  inflated: articles/Greyjoy.txt
#  inflated: articles/Laenor_Velaryon.txt
#  inflated: articles/Jazzy_de_Lisser.txt
#  inflated: articles/Malakho.txt
#  inflated: articles/Arya_Stark_and_Gendry_Baratheon.txt
#  inflated: articles/Battle_of_Castle_Black.txt
#  inflated: articles/Assassination_of_Dalton_Greyjoy.txt
#  inflated: articles/Dean_Weir.txt
#  inflated: articles/Greenblood.txt
#  inflated: articles/Gina_Moxley.txt
#  inflated: articles/The_Sack_of_King%27s_Landing.txt
#  inflated: articles/Bronze_King.txt
#  inflated: articles/Castle_Cerwyn.txt
#  inflated: articles/Dragonstone.txt
#  inflated: articles/Mole%27s_Town_madam.txt
#  inflated: articles/Gorne_and_Gendel%27s_War.txt
#  inflated: articles/Penn.txt
#  inflated: articles/Peter_Silverleaf.txt
#  inflated: articles/Wight.txt
#  inflated: articles/House_Sparr.txt
#  inflated: articles/Miriam_Baratheon.txt
#  inflated: articles/Torrhen%E2%80%99s_Square.txt
#  inflated: articles/King%27s_Landing_whore_(Lord_Snow).txt
#  inflated: articles/Blackhaven.txt
#  inflated: articles/Robar_II_Royce.txt
#  inflated: articles/Viserys_Targaryen.txt
#  inflated: articles/Lord_of_Honeyholt.txt
#  inflated: articles/Basilisk_Isles.txt
#  inflated: articles/Bastard_Letter.txt
#  inflated: articles/Cerwyn.txt
#  inflated: articles/Maelor_Targaryen.txt
#  inflated: articles/Lord_of_Blackmont.txt
#  inflated: articles/Robin_Earle.txt
#  inflated: articles/Moonsinger_Lane.txt
#  inflated: articles/Naomi_Watts.txt
#  inflated: articles/Raymond_Keane.txt
#  inflated: articles/Serwyn_Errol.txt
#  inflated: articles/Laura_Pradelska.txt
#  inflated: articles/House_Harroway.txt
#  inflated: articles/Retaking_of_the_Iron_Islands.txt
#  inflated: articles/Erol_Mehmet.txt
#  inflated: articles/Burning_of_the_Iron_Islands.txt
#  inflated: articles/Blood_Magic.txt
#  inflated: articles/Castellan.txt
#  inflated: articles/House_Marsh.txt
#  inflated: articles/Dwarf_5.txt
#  inflated: articles/Anguy.txt
#  inflated: articles/Game_of_Thrones_Season_7.txt
#  inflated: articles/House_Grandison.txt
#  inflated: articles/Illyrio_Mopatis%27s_first_wife.txt
#  inflated: articles/Jan_Petrina.txt
#  inflated: articles/House_Lannister,_Kings_of_the_Rock_%26_House_Gardener,_Kings_of_the_Reach.txt
#  inflated: articles/Niamh_Lennon.txt
#  inflated: articles/Yi_Ti.txt
#  inflated: articles/Forzo.txt
#  inflated: articles/John_Stahl.txt
#  inflated: articles/Siege_of_Pyke.txt
#  inflated: articles/Kennelmaster.txt
#  inflated: articles/The_Summer_Sea.txt
#  inflated: articles/Conan_Stevens.txt
#  inflated: articles/David_Franklin.txt
#  inflated: articles/Kristy_Robinson.txt
#  inflated: articles/Axel_Tully.txt
#  inflated: articles/Stonesnake.txt
#  inflated: articles/Elizabeth_Webster.txt
#  inflated: articles/Paddy_Considine.txt
#  inflated: articles/Haegon_Blackfyre.txt
#  inflated: articles/Lords_Paramount_of_the_Riverlands.txt
#  inflated: articles/Lommy.txt
#  inflated: articles/House_Bolton_(Histories_%26_Lore).txt
#  inflated: articles/Game_of_Thrones_filming_locations.txt
#  inflated: articles/Hallis_Mollen.txt
#  inflated: articles/Aberdolf_Strongbeard.txt
#  inflated: articles/Musician_3_(The_Lion_and_the_Rose).txt
#  inflated: articles/Dwarfs.txt
#  inflated: articles/Daniel_Minahan.txt
#  inflated: articles/Dermot_Ward.txt
#  inflated: articles/Ser_Loras_Tyrell.txt
#  inflated: articles/Oengus_MacNamara.txt
#  inflated: articles/Argilac_the_Arrogant.txt
#  inflated: articles/House_Holt.txt
#  inflated: articles/Aegon_V_Targaryen.txt
#  inflated: articles/Otto_Hightower.txt
#  inflated: articles/Walda_Bolton.txt
#  inflated: articles/Laura_Bailey.txt
#  inflated: articles/Eglantine.txt
#  inflated: articles/Darran_Watt.txt
#  inflated: articles/Serra_Frey.txt
#  inflated: articles/Clare_Kilner.txt
#  inflated: articles/Barrowton.txt
#  inflated: articles/Filip_Lozi%C4%87.txt
#  inflated: articles/Arwaya_Frey.txt
#  inflated: articles/Basilisk_blood.txt
#  inflated: articles/Robbie_Beggs.txt
#  inflated: articles/Matt_Hermiston.txt
#  inflated: articles/Lord_of_White_Harbor.txt
#  inflated: articles/Gerard_Naprous.txt
#  inflated: articles/Dezhor_zo_Raza.txt
#  inflated: articles/Searoad.txt
#  inflated: articles/Ryger_Rivers.txt
#  inflated: articles/Andalos.txt
#  inflated: articles/Davos_Dayne.txt
#  inflated: articles/Baelor.txt
#  inflated: articles/Seven_Kingdoms.txt
#  inflated: articles/Gulltown.txt
#  inflated: articles/House_Stokeworth.txt
#  inflated: articles/Godswife.txt
#  inflated: articles/Hannah_Waddingham.txt
#  inflated: articles/Spearwife.txt
#  inflated: articles/Andal.txt
#  inflated: articles/Sack_of_Qohor.txt
#  inflated: articles/Nina_Yndis.txt
#  inflated: articles/Dermot_Keaney.txt
#  inflated: articles/Benya_Umber.txt
#  inflated: articles/Casterly_Rock.txt
#  inflated: articles/Myk.txt
#  inflated: articles/Yandel.txt
#  inflated: articles/Lem.txt
#  inflated: articles/Iain_Umber_(son_of_Gareth).txt
#  inflated: articles/Caren_Umber.txt
#  inflated: articles/War_of_the_Five_Kings.txt
#  inflated: articles/Lord_Snow.txt
#  inflated: articles/Aegon_Targaryen_(son_of_Aenys).txt
#  inflated: articles/Goldenheart.txt
#  inflated: articles/Andrew_Wilde.txt
#  inflated: articles/Joffrey_Velaryon.txt
#  inflated: articles/Gerardys.txt
#  inflated: articles/House_Wylde.txt
#  inflated: articles/Old_Ghis_%26_Slaver%27s_Bay.txt
#  inflated: articles/Goatherd_(The_Laws_of_Gods_and_Men).txt
#  inflated: articles/Battle_of_Deepwood_Motte.txt
#  inflated: articles/Yara_Greyjoy.txt
#  inflated: articles/Tommard_Karstark.txt
#  inflated: articles/Jack_Jag.txt
#  inflated: articles/Qhorwyn_Hoare.txt
#  inflated: articles/James_Cox.txt
#  inflated: articles/Rhaella_Targaryen.txt
#  inflated: articles/Gerhard_Forrester.txt
#  inflated: articles/Jane_McGrath.txt
#  inflated: articles/Major_characters.txt
#  inflated: articles/Mountains_of_the_Moon.txt
#  inflated: articles/Ed_Skrein.txt
#  inflated: articles/House_Ryswell.txt
#  inflated: articles/Stentey_Hunter.txt
#  inflated: articles/Losers.txt
#  inflated: articles/Voice_of_Oldtown.txt
#  inflated: articles/Joss_Stilwood.txt
#  inflated: articles/Jefferson_Hall.txt
#  inflated: articles/High_Septon_(boy).txt
#  inflated: articles/Blackwater_Bay.txt
#  inflated: articles/Flynn_Baratheon.txt
#  inflated: articles/Tullys.txt
#  inflated: articles/The_Last_of_the_Starks.txt
#  inflated: articles/Edin_Duffy.txt
#  inflated: articles/Josef_Altin.txt
#  inflated: articles/Mark_Stanley.txt
#  inflated: articles/Known_world.txt
#  inflated: articles/Oznak_zo_Pahl.txt
#  inflated: articles/Une.txt
#  inflated: articles/Ferenc_Berecz.txt
#  inflated: articles/Golden_Tooth.txt
#  inflated: articles/Elia_Sand.txt
#  inflated: articles/Hattie_Gotobed.txt
#  inflated: articles/Raycho_Vasilev.txt
#  inflated: articles/Septa_Unella.txt
#  inflated: articles/King%27s_Landing_flasher.txt
#  inflated: articles/Tristan_McConnell.txt
#  inflated: articles/Harry_Grasby.txt
#  inflated: articles/Eunuchs.txt
#  inflated: articles/Cedric_Storm.txt
#  inflated: articles/Therrond.txt
#  inflated: articles/Hodor.txt
#  inflated: articles/Daemon_II_Blackfyre.txt
#  inflated: articles/Farlen.txt
#  inflated: articles/Baelor_the_Blessed.txt
#  inflated: articles/Street_tough_1.txt
#  inflated: articles/Defender_of_the_Ironwood_Groves.txt
#  inflated: articles/Finn_Watson.txt
#  inflated: articles/Lord_of_Griffin%27s_Roost.txt
#  inflated: articles/House_Branfield.txt
#  inflated: articles/Breaker_of_Chains.txt
#  inflated: articles/Arthur.txt
#  inflated: articles/Gary_Oliver.txt
#  inflated: articles/Brammax_Egen.txt
#  inflated: articles/Knight_of_House_Frey.txt
#  inflated: articles/Bloodriders.txt
#  inflated: articles/Red_Comet.txt
#  inflated: articles/Claire_Connor.txt
#  inflated: articles/House_Blackwood.txt
#  inflated: articles/Bea_Glancy.txt
#  inflated: articles/Mountain_King.txt
#  inflated: articles/Jane_Espenson.txt
#  inflated: articles/Garden_of_Bones.txt
#  inflated: articles/Darrell_D%27Silva.txt
#  inflated: articles/Tara_Fitzgerald.txt
#  inflated: articles/Conclave.txt
#  inflated: articles/Horse.txt
#  inflated: articles/House_Royce.txt
#  inflated: articles/Dothraki_(disambiguation).txt
#  inflated: articles/Winter_town.txt
#  inflated: articles/Dothraki_man_having_sex.txt
#  inflated: articles/Kiran_Shah.txt
#  inflated: articles/Tommy_Dunne.txt
#  inflated: articles/Street_tough_2.txt
#  inflated: articles/Kovarro.txt
#  inflated: articles/Rhogar.txt
#  inflated: articles/Knight_of_Cornfield.txt
#  inflated: articles/Joramun.txt
#  inflated: articles/Erik.txt
#  inflated: articles/House_Qoherys.txt
#  inflated: articles/Protestor.txt
#  inflated: articles/Barra.txt
#  inflated: articles/Pono.txt
#  inflated: articles/Dragonstone_(episode).txt
#  inflated: articles/Talia_Forrester.txt
#  inflated: articles/Cleon.txt
#  inflated: articles/Snow_bear.txt
#  inflated: articles/Lucy_Aarden.txt
#  inflated: articles/Magic.txt
#  inflated: articles/Retaking_of_Harrenhal.txt
#  inflated: articles/Ti_Mikkel.txt
#  inflated: articles/Maid_of_the_Field.txt
#  inflated: articles/Whore%27s_Gash.txt
#  inflated: articles/Maynard_(High_Septon).txt
#  inflated: articles/Bobby_Marno.txt
#  inflated: articles/Maegor_III_Targaryen.txt
#  inflated: articles/Cave_people.txt
#  inflated: articles/Brendan_Cowell.txt
#  inflated: articles/Karl_Jackson.txt
#  inflated: articles/Hizdahr_zo_Loraq.txt
#  inflated: articles/Dragonstone_(Histories_%26_Lore).txt
#  inflated: articles/Oxcross.txt
#  inflated: articles/Lucy_Hayes.txt
#  inflated: articles/Gatins.txt
#  inflated: articles/Elisa_Lasowski.txt
#  inflated: articles/House_Manderly.txt
#  inflated: articles/Lord_of_Storm%27s_End.txt
#  inflated: articles/Robin_Atkin_Downes.txt
#  inflated: articles/Steffon_Trant.txt
#  inflated: articles/Defender_of_the_Vale.txt
#  inflated: articles/Boake.txt
#  inflated: articles/Runestone.txt
#  inflated: articles/Alik_Sakharov.txt
#  inflated: articles/The_Prince_That_Was_Promised.txt
#  inflated: articles/Marek_Blackbrow.txt
#  inflated: articles/Eugene_Simon.txt
#  inflated: articles/Janos_Slynt.txt
#  inflated: articles/Danny_Kirrane.txt
#  inflated: articles/Wolfsbane.txt
#  inflated: articles/Red_Keep.txt
#  inflated: articles/Hannah_Murray.txt
#  inflated: articles/House_Mallister.txt
#  inflated: articles/Lord_of_Light.txt
#  inflated: articles/Ian_Gelder.txt
#  inflated: articles/Harald_Karstark.txt
#  inflated: articles/Valyrian_(ship).txt
#  inflated: articles/Viserys_I_Targaryen.txt
#  inflated: articles/First_Men.txt
#  inflated: articles/Clea.txt
#  inflated: articles/House_Hoare.txt
#  inflated: articles/Willa_(The_Last_of_the_Starks).txt
#  inflated: articles/Old_Anchor.txt
#  inflated: articles/The_Old_Gods_and_the_New_(Complete_Guide_to_Westeros).txt
#  inflated: articles/First_mate.txt
#  inflated: articles/Oldstones.txt
#  inflated: articles/Pixomondo.txt
#  inflated: articles/Tourneys.txt
#  inflated: articles/Kevin_Morgan.txt
#  inflated: articles/Lord_Commander_of_the_Night%27s_Watch.txt
#  inflated: articles/Owen_Whitelaw.txt
#  inflated: articles/Highgarden.txt
#  inflated: articles/Whitehill_(lady).txt
#  inflated: articles/Dirah.txt
#  inflated: articles/Harrenhal.txt
#  inflated: articles/The_Dance_of_Dragons.txt
#  inflated: articles/Occupation_of_Sunspear.txt
#  inflated: articles/Edwell_Celtigar.txt
#  inflated: articles/Milk_of_the_poppy.txt
#  inflated: articles/Kaeth.txt
#  inflated: articles/Hizdahr_zo_Loraq%27s_manservant.txt
#  inflated: articles/Attainting.txt
#  inflated: articles/Wildling_2.txt
#  inflated: articles/Ciaran_Bermingham.txt
#  inflated: articles/Aeryn_Walker.txt
#  inflated: articles/Inside_HBO%27s_Game_of_Thrones.txt
#  inflated: articles/Jason_Oettl%C3%A9.txt
#  inflated: articles/Battle_of_the_Fist_of_the_First_Men.txt
#  inflated: articles/Leyton_Hightower.txt
#  inflated: articles/Tyanna_of_the_Tower.txt
#  inflated: articles/Eastwatch.txt
#  inflated: articles/Patrick_Molloy.txt
#  inflated: articles/Trial_of_Petyr_Baelish.txt
#  inflated: articles/Kingdom_of_the_Isles_and_the_Rivers.txt
#  inflated: articles/Prophecies_of_the_Known_World.txt
#  inflated: articles/Silver.txt
#  inflated: articles/Frostfinger.txt
#  inflated: articles/Talisa_Stark.txt
#  inflated: articles/Languages.txt
#  inflated: articles/Robar_Royce_(lord).txt
#  inflated: articles/The_Kingsguard.txt
#  inflated: articles/Night%27s_Watch_man_2.txt
#  inflated: articles/Maegi.txt
#  inflated: articles/Ella_Tweed.txt
#  inflated: articles/Domeric_Bolton.txt
#  inflated: articles/Sentinel.txt
#  inflated: articles/Khalar_vezhven.txt
#  inflated: articles/Qohor.txt
#  inflated: articles/White_Walker_(Winter_Is_Coming).txt
#  inflated: articles/Poisons.txt
#  inflated: articles/Tess.txt
#  inflated: articles/Valyria.txt
#  inflated: articles/Tyrion_Lannister.txt
#  inflated: articles/Nicholas_Blane.txt
#  inflated: articles/Dusk_Rose.txt
#  inflated: articles/Josh_Dyer.txt
#  inflated: articles/Uprising_in_Sunspear.txt
#  inflated: articles/Hills_of_Andalos.txt
#  inflated: articles/Gordon_Mahn.txt
#  inflated: articles/Dornish_sand_steed.txt
#  inflated: articles/Greyjoy_Rebellion.txt
#  inflated: articles/House_Dormund.txt
#  inflated: articles/House_Ashford.txt
#  inflated: articles/Broken_Branch.txt
#  inflated: articles/Sorcerer.txt
#  inflated: articles/Jaryd_Headley.txt
#  inflated: articles/Joss_(Unbowed,_Unbent,_Unbroken).txt
#  inflated: articles/Lyman_Lannister.txt
#  inflated: articles/Valyrian_stone.txt
#  inflated: articles/Alys_Arryn.txt
#  inflated: articles/House_Baratheon.txt
#  inflated: articles/Phelim_Kelly.txt
#  inflated: articles/Ethelide_Baratheon.txt
#  inflated: articles/Skahazadhan.txt
#  inflated: articles/Mole%27s_Town_whore.txt
#  inflated: articles/Kate_Dempsey.txt
#  inflated: articles/Three-Eyed_Raven.txt
#  inflated: articles/Dorea_Sand.txt
#  inflated: articles/House_Elliver.txt
#  inflated: articles/Great_Master_2_(Breaker_of_Chains).txt
#  inflated: articles/Chelsea_Mainwaring.txt
#  inflated: articles/Lannister_torturer.txt
#  inflated: articles/Kelly_Dent.txt
#  inflated: articles/Mackenzie_Crook.txt
#  inflated: articles/House_Targaryen.txt
#  inflated: articles/Great_Spring_Sickness.txt
#  inflated: articles/Lords_Paramount_of_the_North.txt
#  inflated: articles/Tamaryn_Payne.txt
#  inflated: articles/Gwyneth_Keyworth.txt
#  inflated: articles/Common_tongue.txt
#  inflated: articles/Gary_Greenberg.txt
#  inflated: articles/Rhodri_Hosking.txt
#  inflated: articles/Tim_McInnerny.txt
#  inflated: articles/Ibben.txt
#  inflated: articles/Mutineers.txt
#  inflated: articles/Southerner.txt
#  inflated: articles/Duff.txt
#  inflated: articles/Lord_of_Winterfell.txt
#  inflated: articles/Lord_of_Runestone.txt
#  inflated: articles/Attendant.txt
#  inflated: articles/Lisa_Walsh.txt
#  inflated: articles/Nikovich_Sammut.txt
#  inflated: articles/William_Baratheon_(son_of_William).txt
#  inflated: articles/Aenar_Targaryen.txt
#  inflated: articles/Sam_Parham.txt
#  inflated: articles/Munkun.txt
#  inflated: articles/Green_lands.txt
#  inflated: articles/Michael_Yare.txt
#  inflated: articles/Karstark_lookout.txt
#  inflated: articles/Roslin_Tully.txt
#  inflated: articles/Others.txt
#  inflated: articles/James_O%27Dee.txt
#  inflated: articles/Hill_tribes.txt
#  inflated: articles/An_History_of_the_House_of_Lannister.txt
#  inflated: articles/Christopher_Pocock.txt
#  inflated: articles/Sonoya_Mizuno.txt
#  inflated: articles/Derek_Halligan.txt
#  inflated: articles/Velizar_Peev.txt
#  inflated: articles/Matthar.txt
#  inflated: articles/Aemma_Arryn.txt
#  inflated: articles/Matija_Petrovic.txt
#  inflated: articles/Mummer_2.txt
#  inflated: articles/Blackmont.txt
#  inflated: articles/Louis_Agbodo.txt
#  inflated: articles/Karl_Whitehill.txt
#  inflated: articles/High_Septon_(before_the_Riot_of_King%27s_Landing).txt
#  inflated: articles/House_Tully.txt
#  inflated: articles/Lord_Harroway%27s_Town.txt
#  inflated: articles/Rhoyne.txt
#  inflated: articles/John_Bradley-West.txt
#  inflated: articles/Tom_Brooke.txt
#  inflated: articles/Michelle_Costello.txt
#  inflated: articles/Castle_Stokeworth.txt
#  inflated: articles/Jason_McLaughlin.txt
#  inflated: articles/Widow%27s_Wail.txt
#  inflated: articles/Frey_(founder).txt
#  inflated: articles/Grey_Cliffs.txt
#  inflated: articles/Trial_by_seven_of_Maegor_Targaryen.txt
#  inflated: articles/Ny_Sar.txt
#  inflated: articles/Blackwater_Rush.txt
#  inflated: articles/House_Lothston.txt
#  inflated: articles/Triarchs.txt
#  inflated: articles/Northerner.txt
#  inflated: articles/Pilou_Asb%C3%A6k.txt
#  inflated: articles/House_Mooton.txt
#  inflated: articles/Dark_Sister.txt
#  inflated: articles/Matthos_Seaworth.txt
#  inflated: articles/Emma_Bryant.txt
#  inflated: articles/Obella_Sand.txt
#  inflated: articles/Stewart_James.txt
#  inflated: articles/Golden_Company.txt
#  inflated: articles/Adele_Smyth-Kennedy.txt
#  inflated: articles/Dave_Fisher.txt
#  inflated: articles/Yunkai%27i_slave_6.txt
#  inflated: articles/Archie.txt
#  inflated: articles/Gold_dragons.txt
#  inflated: articles/The_Death_of_Kings.txt
#  inflated: articles/Gilly.txt
#  inflated: articles/Histories_%26_Lore.txt
#  inflated: articles/Owen_Merryweather.txt
#  inflated: articles/Addam_Velaryon.txt
#  inflated: articles/Malcolm.txt
#  inflated: articles/Garth_Greenhand.txt
#  inflated: articles/Battle_at_the_Mummer%27s_Ford.txt
#  inflated: articles/Rhaenys_Targaryen_(sister_of_Aegon_I).txt
#  inflated: articles/Lorcan_Strain.txt
#  inflated: articles/B%C3%A9la_Ors%C3%A1nyi.txt
#  inflated: articles/Waldron_Frey.txt
#  inflated: articles/Kinvara.txt
#  inflated: articles/R%27hllor.txt
#  inflated: articles/Winter_is_coming.txt
#  inflated: articles/House_Glenmore.txt
#  inflated: articles/Pyat_Pree.txt
#  inflated: articles/First_Clegane.txt
#  inflated: articles/Craster%27s_wives.txt
#  inflated: articles/Ralf_Kenning.txt
#  inflated: articles/House_Cargyll.txt
#  inflated: articles/Simpson.txt
#  inflated: articles/God_of_the_Sea.txt
#  inflated: articles/Michael_Johnston.txt
#  inflated: articles/Terry_Byrne.txt
#  inflated: articles/The_Greyjoy_Rebellion.txt
#  inflated: articles/Battle_of_the_Gullet.txt
#  inflated: articles/Great_Master_3_(Breaker_of_Chains).txt
#  inflated: articles/Denise_Gough.txt
#  inflated: articles/Savior_of_the_City.txt
#  inflated: articles/Little_Bird_1.txt
#  inflated: articles/Bronzegate.txt
#  inflated: articles/Drowned_Man.txt
#  inflated: articles/Bronn%27s_House.txt
#  inflated: articles/Talbot.txt
#  inflated: articles/Blackmont_(lord).txt
#  inflated: articles/Tansy.txt
#  inflated: articles/Rhaelle_Targaryen.txt
#  inflated: articles/Eddard_Stark.txt
#  inflated: articles/Hoster_Tully.txt
#  inflated: articles/Theon_Greyjoy%27s_master_of_hounds.txt
#  inflated: articles/Paul_Portelli.txt
#  inflated: articles/All_History_of_the_House_of_Lannister.txt
#  inflated: articles/Laura_Elphinstone.txt
#  inflated: articles/House_Tyrell_(Histories_%26_Lore).txt
#  inflated: articles/Massacre_in_the_Red_Keep.txt
#  inflated: articles/Johnna.txt
#  inflated: articles/Eamon_Keenan.txt
#  inflated: articles/Daemon_III_Blackfyre.txt
#  inflated: articles/Lancel_Lannister.txt
#  inflated: articles/Jesus_Lopez.txt
#  inflated: articles/Noel_Harron.txt
#  inflated: articles/Northward_Ho!.txt
#  inflated: articles/Rast.txt
#  inflated: articles/Chris_Stapleton.txt
#  inflated: articles/Wilko_Johnson.txt
#  inflated: articles/Despondent_man.txt
#  inflated: articles/King%27s_Hand.txt
#  inflated: articles/Bastard%27s_Girls.txt
#  inflated: articles/Gryff_Whitehill.txt
#  inflated: articles/Luke_McEwan.txt
#  inflated: articles/Leech_ritual.txt
#  inflated: articles/House_Follard.txt
#  inflated: articles/Toks_Olagundoye.txt
#  inflated: articles/Bolton_soldier_(Walk_of_Punishment).txt
#  inflated: articles/Weeping_Woman.txt
#  inflated: articles/House_Slynt.txt
#  inflated: articles/Ghiscar.txt
#  inflated: articles/Xander_Royce.txt
#  inflated: articles/Greatjon_Umber.txt
#  inflated: articles/Stranger.txt
#  inflated: articles/Jon_Karstark.txt
#  inflated: articles/Greyscale_%26_The_Stone_Men.txt
#  inflated: articles/Lannister_guard_1.txt
#  inflated: articles/Ceryse_Hightower.txt
#  inflated: articles/Nick_Hobbs.txt
#  inflated: articles/Raquel_Arraes.txt
#  inflated: articles/Donagh_Deeney.txt
#  inflated: articles/Jaime-Cersei_sex_scene.txt
#  inflated: articles/Children_of_the_Forest.txt
#  inflated: articles/Tarbeck_Hall.txt
#  inflated: articles/Jake_Cox.txt
#  inflated: articles/Ania_Bukstein.txt
#  inflated: articles/Coldwater.txt
#  inflated: articles/Lucy_Allen.txt
#  inflated: articles/Donal_Royce_(son_of_Donal).txt
#  inflated: articles/House_Baratheon_of_Dragonstone.txt
#  inflated: articles/Daemon_Targaryen.txt
#  inflated: articles/Temple_of_the_Graces.txt
#  inflated: articles/Dagger_Lake.txt
#  inflated: articles/Beyond_the_Wall_(episode).txt
#  inflated: articles/Qano.txt
#  inflated: articles/Twins.txt
#  inflated: articles/Grag.txt
#  inflated: articles/Ors%C3%A1nyi_Iv%C3%A1n.txt
#  inflated: articles/Brendan_Morrissey.txt
#  inflated: articles/Dave_Forman.txt
#  inflated: articles/Vladimir_Furdik.txt
#  inflated: articles/Emily_Carey.txt
#  inflated: articles/Rhoynish_Wars.txt
#  inflated: articles/Lucy_Murray.txt
#  inflated: articles/Quillion.txt
#  inflated: articles/Hothor_Umber.txt
#  inflated: articles/Christine_Korade_Getos.txt
#  inflated: articles/First_Servant_of_the_Lord_of_Light.txt
#  inflated: articles/Simon_Armstrong.txt
#  inflated: articles/Order_of_Maesters.txt
#  inflated: articles/Bharbo.txt
#  inflated: articles/A.J_Kennedy.txt
#  inflated: articles/Aimee_Richardson.txt
#  inflated: articles/Doreah.txt
#  inflated: articles/Roy_Taylor.txt
#  inflated: articles/Sea_of_Myrth.txt
#  inflated: articles/Battle_Isle.txt
#  inflated: articles/Battle_of_the_Green_Fork.txt
#  inflated: articles/Aegon_I.txt
#  inflated: articles/Andros.txt
#  inflated: articles/Chelsea_Wolfe.txt
#  inflated: articles/House_Celtigar.txt
#  inflated: articles/Darren_Killeen.txt
#  inflated: articles/Samwell_Tarly_and_Gilly.txt
#  inflated: articles/Maron_Greyjoy.txt
#  inflated: articles/Michele_Clapton.txt
#  inflated: articles/Vaes_Dothrak_(Histories_%26_Lore).txt
#  inflated: articles/Aegonfort.txt
#  inflated: articles/Vulture_Hunt.txt
#  inflated: articles/Omar_Youssef.txt
#  inflated: articles/Night%27s_Watch_officer_(The_North_Remembers).txt
#  inflated: articles/Kim_McGarrity.txt
#  inflated: articles/Fionnuala_Murphy.txt
#  inflated: articles/Mountain_clans.txt
#  inflated: articles/Bolton_guard.txt
#  inflated: articles/Gaspar_Szabo.txt
#  inflated: articles/Innkeeper.txt
#  inflated: articles/Natasha_Loring.txt
#  inflated: articles/Steffon_Baratheon_(son_of_Serac).txt
#  inflated: articles/Andrew_Bryan.txt
#  inflated: articles/Dothraki_sea.txt
#  inflated: articles/Hornvale.txt
#  inflated: articles/Matthew_Scurfield.txt
#  inflated: articles/Alton_Lannister.txt
#  inflated: articles/Steve_Cash.txt
#  inflated: articles/Carl_Prekopp.txt
#  inflated: articles/Deziel_Dalt.txt
#  inflated: articles/Blood_of_My_Blood.txt
#  inflated: articles/Wibberley_(lord).txt
#  inflated: articles/Viola_Redwyne.txt
#  inflated: articles/Razdal_mo_Eraz.txt
#  inflated: articles/House_Drumm.txt
#  inflated: articles/Battle_of_Yunkai.txt
#  inflated: articles/Peter_Olivant.txt
#  inflated: articles/Murmison.txt
#  inflated: articles/Luke.txt
#  inflated: articles/Irma_Mali.txt
#  inflated: articles/Prince_of_Dorne.txt
#  inflated: articles/Saltpans.txt
#  inflated: articles/Royal_Steward.txt
#  inflated: articles/Thorren_Forrester.txt
#  inflated: articles/Religion.txt
#  inflated: articles/Saltspear.txt
#  inflated: articles/Ironborn.txt
#  inflated: articles/Robert_Yates.txt
#  inflated: articles/Stark_guard_(A_Man_Without_Honor).txt
#  inflated: articles/Marlin_Dormund.txt
#  inflated: articles/Salt_wives.txt
#  inflated: articles/Kingsmoot.txt
#  inflated: articles/Nina_Gold.txt
#  inflated: articles/Brothel_guard.txt
#  inflated: articles/Qarlton_Chelsted.txt
#  inflated: articles/Frank_Jakeman.txt
#  inflated: articles/Peter_Miles.txt
#  inflated: articles/Wendel.txt
#  inflated: articles/Freys.txt
#  inflated: articles/Chloe_Bruce.txt
#  inflated: articles/Malcolm_Branfield.txt
#  inflated: articles/Morgan_(Two_Swords).txt
#  inflated: articles/Winterfell_(disambiguation).txt
#  inflated: articles/House_Glover.txt
#  inflated: articles/Ironborn_2_(Winterfell).txt
#  inflated: articles/Water_Dance.txt
#  inflated: articles/Sheepstealer.txt
#  inflated: articles/Night%27s_Queen.txt
#  inflated: articles/Ross_Mullan.txt
#  inflated: articles/Braavos.txt
#  inflated: articles/House_Frost.txt
#  inflated: articles/Kenneth_Hadley.txt
#  inflated: articles/Game_of_Thrones_Wiki.txt
#  inflated: articles/Lordsport_dockhand.txt
#  inflated: articles/Aelinor_Targaryen.txt
#  inflated: articles/Conor_Watters.txt
#  inflated: articles/Great_Masters.txt
#  inflated: articles/Javier_Botet.txt
#  inflated: articles/Brahm_Gallagher.txt
#  inflated: articles/Battle_of_the_Golden_Tooth.txt
#  inflated: articles/Rob_de_Groot.txt
#  inflated: articles/House_Gaunt.txt
#  inflated: articles/Gold_Cloak.txt
#  inflated: articles/Maynard_Royce.txt
#  inflated: articles/First_Battle_of_Deepwood_Motte.txt
#  inflated: articles/Vermithrax.txt
#  inflated: articles/Lord_of_Tarbeck_Hall.txt
#  inflated: articles/House_Belgrave.txt
#  inflated: articles/Curtis_Rivers.txt
#  inflated: articles/Ellyn_Reyne.txt
#  inflated: articles/Sons_of_the_Harpy.txt
#  inflated: articles/Rob_Cooper.txt
#  inflated: articles/Cersei_sex_scene_in_%22Breaker_of_Chains%22.txt
#  inflated: articles/Karen_Xuereb.txt
#  inflated: articles/Barrington_Cullen.txt
#  inflated: articles/White_Walker_(The_Dragon_and_the_Wolf).txt
#  inflated: articles/Steward.txt
#  inflated: articles/Kullback.txt
#  inflated: articles/Lead_Kingsguard.txt
#  inflated: articles/Battle_of_the_Seven_Stars.txt
#  inflated: articles/Qyle_Corbray.txt
#  inflated: articles/Helliweg.txt
#  inflated: articles/Will_O%27Connell.txt
#  inflated: articles/Michael_Hanna.txt
#  inflated: articles/Gentle_Mother,_Font_of_Mercy.txt
#  inflated: articles/Hedge_knight.txt
#  inflated: articles/Rori_Hawthorn.txt
#  inflated: articles/House_Leygood.txt
#  inflated: articles/Gary_Connery.txt
#  inflated: articles/Colen.txt
#  inflated: articles/Frank_Blake.txt
#  inflated: articles/Timett.txt
#  inflated: articles/Stephen_Brown.txt
#  inflated: articles/Brian_Nickels.txt
#  inflated: articles/Felix_Jamieson.txt
#  inflated: articles/House_Hunter.txt
#  inflated: articles/Raymun_Darry.txt
#  inflated: articles/Mary_Jordan.txt
#  inflated: articles/Guy_Oliver-Watts.txt
#  inflated: articles/House_Hollard.txt
#  inflated: articles/Rennick.txt
#  inflated: articles/Citadel_maester.txt
#  inflated: articles/Elizabeth_Barrett.txt
#  inflated: articles/Dragonpit.txt
#  inflated: articles/Tyrell_servant.txt
#  inflated: articles/Stone_Hedge.txt
#  inflated: articles/Green_Council.txt
#  inflated: articles/Aerion_Brightflame.txt
#  inflated: articles/Eaton.txt
#  inflated: articles/Annabel_Elizabeth_Wood.txt
#  inflated: articles/Lyonel_Tyrell.txt
#  inflated: articles/Castle_Black.txt
#  inflated: articles/Ashford.txt
#  inflated: articles/Bronn.txt
#  inflated: articles/Alan_McKee.txt
#  inflated: articles/Kingswood.txt
#  inflated: articles/Mother%27s_Mercy.txt
#  inflated: articles/Lord_of_Silverhill.txt
#  inflated: articles/Rape.txt
#  inflated: articles/Titan%27s_Daughter.txt
#  inflated: articles/The_Door.txt
#  inflated: articles/Othell_Yarwyck.txt
#  inflated: articles/Yezzan_zo_Qaggaz.txt
#  inflated: articles/First_Ranger.txt
#  inflated: articles/Tamsin_Greene_Barker.txt
#  inflated: articles/Emer_McDaid.txt
#  inflated: articles/Gethin_Anthony.txt
#  inflated: articles/Annette_Tierney.txt
#  inflated: articles/Falyse_Stokeworth.txt
#  inflated: articles/Miller%27s_wife.txt
#  inflated: articles/Mummer_1.txt
#  inflated: articles/Tamiko_Brownlee.txt
#  inflated: articles/Lorenzo_Casares.txt
#  inflated: articles/Kingdom_of_the_Reach.txt
#  inflated: articles/Tim_Plester.txt
#  inflated: articles/Common_Tongue.txt
#  inflated: articles/Sellswords_%26_Hedge_Knights.txt
#  inflated: articles/Maid_of_the_Seas.txt
#  inflated: articles/Pat_Mooney.txt
#  inflated: articles/Tobias_Winter.txt
#  inflated: articles/Planky_Town.txt
#  inflated: articles/Eddie.txt
#  inflated: articles/Peter_Brown.txt
#  inflated: articles/Yunkai%27i_slave_3.txt
#  inflated: articles/Muddy_Way.txt
#  inflated: articles/Jodhi_May.txt
#  inflated: articles/King%27s_Landing_drunkard.txt
#  inflated: articles/Vulture_King.txt
#  inflated: articles/Dothraki_religion.txt
#  inflated: articles/Jade_Lye.txt
#  inflated: articles/Nell_Williams.txt
#  inflated: articles/House_Staunton.txt
#  inflated: articles/Sty.txt
#  inflated: articles/Crownlands.txt
#  inflated: articles/Jon_Arryn.txt
#  inflated: articles/Lord_2.txt
#  inflated: articles/Sept_of_Remembrance.txt
#  inflated: articles/Stannis_I_Baratheon.txt
#  inflated: articles/Skull_Island.txt
#  inflated: articles/Great_Stallion.txt
#  inflated: articles/Captain_of_the_archers_(House_Lannister).txt
#  inflated: articles/Alys_Reyne.txt
#  inflated: articles/Elliott_Tittensor.txt
#  inflated: articles/Great_Pyramid.txt
#  inflated: articles/Elmo_Walker.txt
#  inflated: articles/House_of_Black_and_White.txt
#  inflated: articles/Pit_fighter.txt
#  inflated: articles/House_Selmy.txt
#  inflated: articles/Sera.txt
#  inflated: articles/Jonquil.txt
#  inflated: articles/Dan_Hartley.txt
#  inflated: articles/Assassination_at_the_Tower_of_the_Hand.txt
#  inflated: articles/Asshai%27i_(disambiguation).txt
#  inflated: articles/Clydas.txt
#  inflated: articles/Bathhouse_prostitute.txt
#  inflated: articles/Natalia_Tena.txt
#  inflated: articles/Aegon_II_Targaryen.txt
#  inflated: articles/Amira_Ghazella.txt
#  inflated: articles/Sam_Stone.txt
#  inflated: articles/Clive_Russell.txt
#  inflated: articles/Vicky.txt
#  inflated: articles/Arthur_(disambiguation).txt
#  inflated: articles/The_Wars_to_Come.txt
#  inflated: articles/First_Sword_of_Braavos.txt
#  inflated: articles/Samuel_Paul_Small.txt
#  inflated: articles/Alexander_Siddig.txt
#  inflated: articles/Old_woman_prisoner.txt
#  inflated: articles/Rescue_of_Yara_Greyjoy.txt
#  inflated: articles/Hardhome.txt
#  inflated: articles/Irene_Kelleher.txt
#  inflated: articles/James_Doran.txt
#  inflated: articles/Lyndon_Hellewell.txt
#  inflated: articles/Mavis_Royce_(daughter_of_Donal).txt
#  inflated: articles/King-Beyond-the-Wall.txt
#  inflated: articles/The_Book_of_Brothers.txt
#  inflated: articles/Food_and_drink.txt
#  inflated: articles/Max_von_Sydow.txt
#  inflated: articles/Osha.txt
#  inflated: articles/Hannah_John-Kamen.txt
#  inflated: articles/Walk_of_Punishment.txt
#  inflated: articles/Caroline_Davis.txt
#  inflated: articles/Myros.txt
#  inflated: articles/Ternesio_Terys.txt
#  inflated: articles/Alee_Fauzi.txt
#  inflated: articles/Matt_Da_Silva.txt
#  inflated: articles/Lannister_captain_(The_Old_Gods_and_the_New).txt
#  inflated: articles/Rogar_Bolton.txt
#  inflated: articles/Ironborn_in_skiff.txt
#  inflated: articles/Gwayne_Corbray.txt
#  inflated: articles/Flaying.txt
#  inflated: articles/Dorne_(Histories_%26_Lore).txt
#  inflated: articles/Yousef_Sweid.txt
#  inflated: articles/House_Allyrion.txt
#  inflated: articles/Capture_of_Riverrun.txt
#  inflated: articles/Derek_Horsham.txt
#  inflated: articles/Prince_of_Winterfell.txt
#  inflated: articles/Robert_Goodman.txt
#  inflated: articles/Siege_of_White_Harbor.txt
#  inflated: articles/Drummer.txt
#  inflated: articles/Kelly_Long.txt
#  inflated: articles/Azor_Ahai.txt
#  inflated: articles/House_Velaryon.txt
#  inflated: articles/Daemon_Sand.txt
#  inflated: articles/Belicho_Paenymion.txt
#  inflated: articles/Kidney_pie.txt
#  inflated: articles/Whore_(The_Mother).txt
#  inflated: articles/Garry_Mountaine.txt
#  inflated: articles/Branfield_(lord).txt
#  inflated: articles/Danelle_Lothston.txt
#  inflated: articles/Cupbearer.txt
#  inflated: articles/Dave_Cronnelly.txt
#  inflated: articles/Moro%27s_wife_2.txt
#  inflated: articles/Leo_Woodruff.txt
#  inflated: articles/Most_Devout.txt
#  inflated: articles/Red.txt
#  inflated: articles/Sally.txt
#  inflated: articles/Art_Parkinson.txt
#  inflated: articles/Mustapha_Rachidi.txt
#  inflated: articles/Sandhu.txt
#  inflated: articles/Tully.txt
#  inflated: articles/Nettles.txt
#  inflated: articles/Jojen_Reed.txt
#  inflated: articles/Benjen_Stark.txt
#  inflated: articles/Talla_Tarly.txt
#  inflated: articles/Moro.txt
#  inflated: articles/Lyanna_Stark.txt
#  inflated: articles/Viserys_Targaryen_(disambiguation).txt
#  inflated: articles/Lu_Corfield.txt
#  inflated: articles/Gerald_McMullan.txt
#  inflated: articles/Durran_Godsgrief.txt
#  inflated: articles/Gold_Cloak_2_(Eastwatch).txt
#  inflated: articles/Annette_Hannah.txt
#  inflated: articles/The_Stallion_Who_Mounts_the_World.txt
#  inflated: articles/Kingdom_of_the_Iron_Islands.txt
#  inflated: articles/Alex_Sharp.txt
#  inflated: articles/Edward_Tudor_Pole.txt
#  inflated: articles/Damien.txt
#  inflated: articles/Alice_Nokes.txt
#  inflated: articles/House_Dayne.txt
#  inflated: articles/Grey_Wind.txt
#  inflated: articles/Cheryl_Lester.txt
#  inflated: articles/The_Free_Cities.txt
#  inflated: articles/Maynard.txt
#  inflated: articles/House_Egen.txt
#  inflated: articles/Ciaran_McMahon.txt
#  inflated: articles/Daeron_I_Targaryen.txt
#  inflated: articles/King%27s_Landing_(Histories_%26_Lore).txt
#  inflated: articles/Duncan_the_Tall.txt
#  inflated: articles/Essie_Davis.txt
#  inflated: articles/Robb_and_Talisa_Stark.txt
#  inflated: articles/Rory_Mulroe.txt
#  inflated: articles/Maegor_the_Cruel.txt
#  inflated: articles/Matt_Wolf.txt
#  inflated: articles/Harpy_(leader).txt
#  inflated: articles/Billy.txt
#  inflated: articles/Old_warhorn.txt
#  inflated: articles/Stannis_Baratheon.txt
#  inflated: articles/Scott_Smith.txt
#  inflated: articles/Quaithe.txt
#  inflated: articles/High_Septon_(Robert%27s_Rebellion).txt
#  inflated: articles/Jos%C3%A9_Mellinas.txt
#  inflated: articles/Polliver.txt
#  inflated: articles/The_Red_Keep.txt
#  inflated: articles/Red_Priests.txt
#  inflated: articles/Raid_on_Craster%27s_Keep.txt
#  inflated: articles/Surrender_of_Moat_Cailin.txt
#  inflated: articles/Mag_Mar_Tun_Doh_Weg.txt
#  inflated: articles/Sea_Dragon_Point.txt
#  inflated: articles/Search_for_the_North_Grove.txt
#  inflated: articles/Stuart_Frift.txt
#  inflated: articles/Thomas_Martin.txt
#  inflated: articles/Uthero_Zalyne.txt
#  inflated: articles/Merling_King.txt
#  inflated: articles/Matt_Littler.txt
#  inflated: articles/Joshua_Sher.txt
#  inflated: articles/Lord_of_Sunspear.txt
#  inflated: articles/Gerold_Hightower.txt
#  inflated: articles/Paint_Hall.txt
#  inflated: articles/Chris_Newton.txt
#  inflated: articles/Temple_of_the_Moonsingers.txt
#  inflated: articles/Salty_Town.txt
#  inflated: articles/Joe_Purcell.txt
#  inflated: articles/Frank_Cannon.txt
#  inflated: articles/Beskha.txt
#  inflated: articles/Kuri.txt
#  inflated: articles/Whore_(Two_Swords).txt
#  inflated: articles/Great_House.txt
#  inflated: articles/Attempted_murder_of_Mira_Forrester.txt
#  inflated: articles/River_Gate.txt
#  inflated: articles/Niko.txt
#  inflated: articles/Paul_Bentley.txt
#  inflated: articles/Arys_Oakheart.txt
#  inflated: articles/Yuri_Lowenthal.txt
#  inflated: articles/Septon_(Valar_Morghulis).txt
#  inflated: articles/Frey_guard.txt
#  inflated: articles/Free_Cities.txt
#  inflated: articles/Elbert_Arryn.txt
#  inflated: articles/Katie_Tumelty.txt
#  inflated: articles/William.txt
#  inflated: articles/Living_Language_Dothraki.txt
#  inflated: articles/Aaron_Archer.txt
#  inflated: articles/Seamus_Kelly.txt
#  inflated: articles/Roger_Allam.txt
#  inflated: articles/Tyene_Sand.txt
#  inflated: articles/Lives_of_Four_Kings.txt
#  inflated: articles/Vance_Corbray.txt
#  inflated: articles/Florian.txt
#  inflated: articles/Borcas.txt
#  inflated: articles/Lann_the_Clever.txt
#  inflated: articles/Steve_Conrad.txt
#  inflated: articles/Jasper_Wylde.txt
#  inflated: articles/David_Cronnelly.txt
#  inflated: articles/Raid_on_Lannisport.txt
#  inflated: articles/Fist_of_the_First_Men.txt
#  inflated: articles/Jafer_Flowers.txt
#  inflated: articles/Axel_Baratheon.txt
#  inflated: articles/Massacre_of_the_khalar_vezhven.txt
#  inflated: articles/Instruction:_Images.txt
#  inflated: articles/Greizhen_mo_Ullhor.txt
#  inflated: articles/Teela.txt
#  inflated: articles/Calvin_Warrington-Heasman.txt
#  inflated: articles/Black_Ears.txt
#  inflated: articles/Morag.txt
#  inflated: articles/Ironmen.txt
#  inflated: articles/Foreign_merchant.txt
#  inflated: articles/Slaver.txt
#  inflated: articles/Yorick_V_Yronwood.txt
#  inflated: articles/Northern_lord_(The_North_Remembers).txt
#  inflated: articles/Acorn_Hall.txt
#  inflated: articles/Animals_and_plants.txt
#  inflated: articles/Wars_of_the_First_Men_and_the_Children_of_the_Forest.txt
#  inflated: articles/Luke_McQuillan.txt
#  inflated: articles/Hugor%27s_bride.txt
#  inflated: articles/Darragh_O%27Connor.txt
#  inflated: articles/Tommax_Baratheon.txt
#  inflated: articles/Will_Dent.txt
#  inflated: articles/Second_Sons_(episode).txt
#  inflated: articles/Janeya_Frey.txt
#  inflated: articles/Shipbreaker_Bay.txt
#  inflated: articles/Cultures_and_peoples.txt
#  inflated: articles/Civic_Guard.txt
#  inflated: articles/Douglas_Wighton.txt
#  inflated: articles/Qarth.txt
#  inflated: articles/Sealord%27s_Palace.txt
#  inflated: articles/Thenn.txt
#  inflated: articles/G%C3%A1sp%C3%A1r_Szab%C3%B3.txt
#  inflated: articles/Willam_the_Wanderer.txt
#  inflated: articles/Stuart_Clark.txt
#  inflated: articles/The_Rains_of_Castamere_(episode).txt
#  inflated: articles/Meereenese_champion.txt
#  inflated: articles/Gendry_Baratheon.txt
#  inflated: articles/Aegon,_First_of_His_Name.txt
#  inflated: articles/Allon_Sylvain.txt
#  inflated: articles/Annabel_Wood.txt
#  inflated: articles/Cillean_Campbell.txt
#  inflated: articles/Milen_Kaleychev.txt
#  inflated: articles/Vencislav_Stoyanov.txt
#  inflated: articles/Fabian_Wagner.txt
#  inflated: articles/Long_Barrow.txt
#  inflated: articles/Showdown_at_the_Tower_of_Joy.txt
#  inflated: articles/Hooded_Wayfarer.txt
#  inflated: articles/Aegon_V.txt
#  inflated: articles/Stark_soldier_(Valar_Morghulis).txt
#  inflated: articles/Mark_Tankersley.txt
#  inflated: articles/Ash.txt
#  inflated: articles/Baelish_keep.txt
#  inflated: articles/Amy_Pemberton.txt
#  inflated: articles/Derek_Dubery.txt
#  inflated: articles/The_Vale.txt
#  inflated: articles/Eduardo_Gago.txt
#  inflated: articles/Stormborn.txt
#  inflated: articles/Northern_Wars.txt
#  inflated: articles/Adam_Leadbeater.txt
#  inflated: articles/Garth_Gardener.txt
#  inflated: articles/Gold_Cloak_2_(The_Wolf_and_the_Lion).txt
#  inflated: articles/Lord_of_Barrowton.txt
#  inflated: articles/Adam_Basil.txt
#  inflated: articles/Flea_Bottom.txt
#  inflated: articles/House_Greenfield.txt
#  inflated: articles/Dothraki_widow_2.txt
#  inflated: articles/Keisha_Castle-Hughes.txt
#  inflated: articles/Maro_Drobnic.txt
#  inflated: articles/Trial_by_combat_of_Sandor_Clegane.txt
#  inflated: articles/Petyr_Baelish.txt
#  inflated: articles/House_Blount.txt
#  inflated: articles/Bald_Dragonstone_servant.txt
#  inflated: articles/Octavia_Alexandru.txt
#  inflated: articles/Simon_Fossoway.txt
#  inflated: articles/Gender_and_sexuality.txt
#  inflated: articles/Amory_Lorch.txt
#  inflated: articles/Fall_of_Last_Hearth.txt
#  inflated: articles/Scolera.txt
#  inflated: articles/Sybelle_Glover.txt
#  inflated: articles/Serena_Blackfyre.txt
#  inflated: articles/Aegon_Blackfyre.txt
#  inflated: articles/King_of_the_Mountain_and_the_Vale.txt
#  inflated: articles/Ormund_Baratheon.txt
#  inflated: articles/Master_torturer.txt
#  inflated: articles/Matthew_Mercer.txt
#  inflated: articles/Blacks.txt
#  inflated: articles/Jeyne_Arryn.txt
#  inflated: articles/Neck.txt
#  inflated: articles/Tony_Flynn.txt
#  inflated: articles/Richard_Hansen.txt
#  inflated: articles/Red_Lake.txt
#  inflated: articles/Frey_pie.txt
#  inflated: articles/Silent_sisters.txt
#  inflated: articles/Brian_Helgeland.txt
#  inflated: articles/Logan_Watson.txt
#  inflated: articles/Ethan_Forrester.txt
#  inflated: articles/Mark_Franklin_Henson.txt
#  inflated: articles/Lannister_soldier.txt
#  inflated: articles/Mhysa.txt
#  inflated: articles/Maidenvault.txt
#  inflated: articles/Zahari_Grozdanov.txt
#  inflated: articles/Game_of_Thrones_pilot_episode.txt
#  inflated: articles/Jonathan_Cowen.txt
#  inflated: articles/Local_Sitemap.txt
#  inflated: articles/Marek_Toth.txt
#  inflated: articles/Eileen_McCloskey.txt
#  inflated: articles/The_Ghost_of_Harrenhal.txt
#  inflated: articles/Hammer_of_the_waters.txt
#  inflated: articles/Vickon_Greyjoy.txt
#  inflated: articles/Grey_Worm.txt
#  inflated: articles/Freerider.txt
#  inflated: articles/Children_of_the_Forest_vs._the_First_Men.txt
#  inflated: articles/Mallister_supporter.txt
#  inflated: articles/Reynard_Reyne.txt
#  inflated: articles/Goran_Goricki.txt
#  inflated: articles/Jenny_Edgar.txt
#  inflated: articles/Shield_Islands.txt
#  inflated: articles/Great_Master_3_(Kill_the_Boy).txt
#  inflated: articles/Oryan_Landa.txt
#  inflated: articles/Game_of_Thrones_Wiki:Policies,_Guidelines_and_Parent_Filter.txt
#  inflated: articles/Simon_Norbury.txt
#  inflated: articles/Stephen_Dillane.txt
#  inflated: articles/Paul_Herbert.txt
#  inflated: articles/Long_Night.txt
#  inflated: articles/Night%27s_King.txt
# ...
#  inflated: articles/Cooper.txt
#  inflated: articles/Alan_Taylor.txt
#  inflated: articles/Robert_Pavey.txt
#  inflated: articles/Rose_Leslie.txt
#  inflated: articles/Aeron_Greyjoy.txt
#  inflated: articles/House_of_Loraq.txt
#  inflated: articles/North_Grove.txt
#  inflated: articles/Triarch.txt
#  inflated: articles/Geza_Kovacs.txt
#  inflated: articles/Craster%27s_last_son.txt
#  inflated: articles/Hardstone_Hills.txt
#  inflated: articles/Tristan_Mudd.txt
#  inflated: articles/Valar_Morghulis.txt
#  inflated: articles/Desmond_Edwards.txt
#  inflated: articles/Lonely_Hills.txt
#  inflated: articles/Othman_Ilyassa.txt
#  inflated: articles/Kyle_Royce.txt
#  inflated: articles/Craster%27s_final_son.txt
#  inflated: articles/Snakewood.txt
#  inflated: articles/Kevin_Eldon.txt
#  inflated: articles/Marlon_of_Tumblestone.txt
#  inflated: articles/Kings_of_Winter.txt
#  inflated: articles/Eve_Best.txt
#  inflated: articles/Abandonment_of_Dragonstone.txt
#  inflated: articles/Lamprey_pie.txt
#  inflated: articles/Heidi_Romanova.txt
#  inflated: articles/Hammerhorn.txt
#  inflated: articles/Joss_(A_Golden_Crown).txt
#  inflated: articles/Ian_Lloyd_Anderson.txt
#  inflated: articles/Owen_Teale.txt
#  inflated: articles/Elaena_Glenmore.txt
#  inflated: articles/House_Thorne.txt
#  inflated: articles/Lord_Paramount_of_the_Westerlands.txt
#  inflated: articles/David_Garrick.txt
#  inflated: articles/Mark_Stanton-Kelly.txt
#  inflated: articles/House_Baelish_(Histories_%26_Lore).txt
#  inflated: articles/Rocky_Taylor.txt
#  inflated: articles/Dwarf_elephant.txt
#  inflated: articles/Razvan_Gheorghiu.txt
#  inflated: articles/Gared_Tuttle.txt
#  inflated: articles/Bobono.txt
#  inflated: articles/House_Merlyn.txt
#  inflated: articles/Gareth_Wright.txt
#  inflated: articles/Dragonpit_Summit.txt
#  inflated: articles/Bogdan_Kumsackij.txt
#  inflated: articles/Chris_Cox.txt
#  inflated: articles/Marquis_Rodriguez.txt
#  inflated: articles/Pablo_Verdejo.txt
#  inflated: articles/Manfred_Hightower.txt
#  inflated: articles/Iggo.txt
#  inflated: articles/Brusco_Bouncer.txt
#  inflated: articles/Martyn_Baratheon.txt
#  inflated: articles/Of_Monsters_and_Men.txt
#  inflated: articles/Ross_McKinney.txt
#  inflated: articles/Old_Way_(disambiguation).txt
#  inflated: articles/Ben_Yates.txt
#  inflated: articles/Sam_(disambiguation).txt
#  inflated: articles/White_Rat.txt
#  inflated: articles/Lannister_spearman.txt
#  inflated: articles/Miguel_%C3%81ngel_Luque.txt
#  inflated: articles/Luna_Kalo.txt
#  inflated: articles/Stephen_Warbeck.txt
#  inflated: articles/Michael_Byrch.txt
#  inflated: articles/Drunk_man.txt
#  inflated: articles/House_Belmore.txt
#  inflated: articles/Lord_Paramount_of_the_North.txt
#  inflated: articles/God_of_Death.txt
#  inflated: articles/Joffrey.txt
#  inflated: articles/Nathanael_Saleh.txt
#  inflated: articles/Orell.txt
#  inflated: articles/A_Golden_Crown.txt
#  inflated: articles/Claire_Wright.txt
#  inflated: articles/Faith_Militant_raid_on_the_Red_Keep.txt
#  inflated: articles/Luke_Wilson_Hanley.txt
#  inflated: articles/Ryan_Corr.txt
#  inflated: articles/Great_Master_6.txt
#  inflated: articles/Robert_Render.txt
#  inflated: articles/Rohanne_Webber.txt
#  inflated: articles/Duncan_Tuttle.txt
#  inflated: articles/Othor.txt
#  inflated: articles/Lucerys_Velaryon.txt
#  inflated: articles/Royal_Fleet.txt
#  inflated: articles/Zach_Roberts.txt
#  inflated: articles/Warlock_(Valar_Dohaeris).txt
#  inflated: articles/House_Connington.txt
#  inflated: articles/House_Casterly.txt
#  inflated: articles/Buster_Reeves.txt
#  inflated: articles/War_for_the_Stepstones.txt
#  inflated: articles/Noble_House.txt
#  inflated: articles/And_Now_His_Watch_Is_Ended.txt
#  inflated: articles/Arbor.txt
#  inflated: articles/Mother_Rhoyne.txt
#  inflated: articles/Freya_Frey.txt
#  inflated: articles/Red_Priest.txt
#  inflated: articles/Rashid_Phoenix.txt
#  inflated: articles/Nail.txt
#  inflated: articles/Dragon.txt
#  inflated: articles/Catspaw_assassin.txt
#  inflated: articles/The_Field_of_Fire.txt
#  inflated: articles/Martin_Lee_Pemberton.txt
#  inflated: articles/The_Riverlands.txt
#  inflated: articles/Kingslaying.txt
#  inflated: articles/Shauna_Duggins.txt
#  inflated: articles/Knight_of_Lemonwood.txt
#  inflated: articles/King%27s_Landing_tailor.txt
#  inflated: articles/Urzen.txt
#  inflated: articles/King%27s_Landing_rioter_2.txt
#  inflated: articles/Slavko_Sobin.txt
#  inflated: articles/Bone_Mountains.txt
#  inflated: articles/Susie_McWilliams.txt
#  inflated: articles/House_Marbrand.txt
#  inflated: articles/The_Red_Woman.txt
#  inflated: articles/Katy_Bullock.txt
#  inflated: articles/Estermont.txt
#  inflated: articles/Duncan_Lacroix.txt
#  inflated: articles/Georgi_Manchev.txt
#  inflated: articles/Pyromancer.txt
#  inflated: articles/Hugh.txt
#  inflated: articles/Paul_Howell.txt
#  inflated: articles/Grumkins_and_snarks.txt
#  inflated: articles/Tomard.txt
#  inflated: articles/Gallowsgrey.txt
#  inflated: articles/Game_of_Thrones:_Music_from_the_HBO_Series_-_Season_5.txt
#  inflated: articles/Elys_Westerling.txt
#  inflated: articles/Paul_Caddell.txt
#  inflated: articles/Giant.txt
#  inflated: articles/Willas_Tyrell.txt
#  inflated: articles/Theon_Greyjoy.txt
#  inflated: articles/Emily_Diamond.txt
#  inflated: articles/Dontos_Hollard.txt
#  inflated: articles/Windblown.txt
#  inflated: articles/Marcus_Shakesheff.txt
#  inflated: articles/Bowls_of_brown.txt
#  inflated: articles/Shane_Roberts.txt
#  inflated: articles/Septons.txt
#  inflated: articles/Red_Temple.txt
#  inflated: articles/Betrayers.txt
#  inflated: articles/Deep_Lake.txt
#  inflated: articles/Donnel_Waynwood.txt
#  inflated: articles/Michelle_Fairley.txt
#  inflated: articles/Ghiscar_(dragon).txt
#  inflated: articles/Ryan_Condal.txt
#  inflated: articles/Runcel_Hightower.txt
#  inflated: articles/Miroslav_Buhin.txt
#  inflated: articles/House_of_the_Undying.txt
#  inflated: articles/Michael_Hough.txt
#  inflated: articles/Rob_Ostlere.txt
#  inflated: articles/Lyonel_Selmy.txt
#  inflated: articles/Willem_Wylde.txt
#  inflated: articles/Lorax_Baratheon.txt
#  inflated: articles/Long_farewell.txt
#  inflated: articles/Morgan%27s_friend.txt
#  inflated: articles/Tyrell_lady.txt
#  inflated: articles/Battle_of_the_Blackwater.txt
#  inflated: articles/Nightfall.txt
#  inflated: articles/Dreadfort.txt
#  inflated: articles/Millicent_Hunter.txt
#  inflated: articles/Chris_Gallagher.txt
#  inflated: articles/Samantha_McEwan.txt
#  inflated: articles/Rob_McElhenney.txt
#  inflated: articles/Camilla_Naprous.txt
#  inflated: articles/Great_Pit_of_Daznak.txt
#  inflated: articles/House_Payne.txt
#  inflated: articles/Blackfyre_Rebellion.txt
#  inflated: articles/House_Mollen.txt
#  inflated: articles/Steward_(Night%27s_Watch).txt
#  inflated: articles/Shaun_Blaney.txt
#  inflated: articles/Brightroar.txt
#  inflated: articles/Byron_Swann.txt
#  inflated: articles/Brightwater_Keep.txt
#  inflated: articles/Battle_of_the_Goldroad.txt
#  inflated: articles/Smalljon_Umber.txt
#  inflated: articles/Jamie_Campbell_Bower.txt
#  inflated: articles/Staz_Nair.txt
#  inflated: articles/Jack_Hickey.txt
#  inflated: articles/Miltos_Yerolemou.txt
#  inflated: articles/House_Uller.txt
#  inflated: articles/Bending_the_knee.txt
#  inflated: articles/Old_Gods_of_the_Forest.txt
#  inflated: articles/Paul_Kealyn.txt
#  inflated: articles/Glass_candle.txt
#  inflated: articles/Black_Goat.txt
#  inflated: articles/Sea_of_Dorne.txt
#  inflated: articles/King_of_Qarth.txt
#  inflated: articles/King%27s_Landing_rioter_1.txt
#  inflated: articles/Elsera_Snow.txt
#  inflated: articles/Charlotte_Hope.txt
#  inflated: articles/Dun_Umber.txt
#  inflated: articles/Bethany_Bracken.txt
#  inflated: articles/John_Bradley_West.txt
#  inflated: articles/Ramsgate.txt
#  inflated: articles/Visneya_Targaryen.txt
#  inflated: articles/Tazal.txt
#  inflated: articles/Barbrey_Ryswell.txt
#  inflated: articles/Andy_Merchant.txt
#  inflated: articles/Olyvar_Frey.txt
#  inflated: articles/Wonders_Made_by_Man.txt
#  inflated: articles/Peter_Guiney.txt
#  inflated: articles/Darlessa_Lannister.txt
#  inflated: articles/Darius_Dar_Khan.txt
#  inflated: articles/Bear_Island.txt
#  inflated: articles/Joseph_Gatt.txt
#  inflated: articles/Garibald_of_the_Seven_Stars.txt
#  inflated: articles/Mad_King_Aerys.txt
#  inflated: articles/Nightfort.txt
#  inflated: articles/Portia_Victoria.txt
#  inflated: articles/Long_Farewell.txt
#  inflated: articles/Reginald_Baratheon.txt
#  inflated: articles/Graham_Charles.txt
#  inflated: articles/Dragonseeds.txt
#  inflated: articles/Fighting_pit.txt
#  inflated: articles/Jon_Costelloe.txt
#  inflated: articles/Stableboy.txt
#  inflated: articles/White_walker.txt
#  inflated: articles/White_Tree.txt
#  inflated: articles/Lodos.txt
#  inflated: articles/Neil_Fingleton.txt
#  inflated: articles/Lottie_Steer.txt
#  inflated: articles/Goldroad.txt
#  inflated: articles/Rila_Fukushima.txt
#  inflated: articles/Maisie_Dee.txt
#  inflated: articles/Ashley_Beck.txt
#  inflated: articles/Escan.txt
#  inflated: articles/Dominic_Carter.txt
#  inflated: articles/Shiera_Seastar.txt
#  inflated: articles/Redfort.txt
#  inflated: articles/Sarsfield.txt
#  inflated: articles/Graces.txt
#  inflated: articles/Nymeria.txt
#  inflated: articles/Ten_Towers.txt
#  inflated: articles/Iron_From_Ice.txt
#  inflated: articles/Fall_of_King%27s_Landing.txt
#  inflated: articles/Simon_Millar.txt
#  inflated: articles/Eastern_road.txt
#  inflated: articles/Afterlife.txt
#  inflated: articles/Red_Wedding.txt
#  inflated: articles/Queen_Regent.txt
#  inflated: articles/DeObia_Oparei.txt
#  inflated: articles/Arthur_Glenmore.txt
#  inflated: articles/Burning_of_the_Sept_of_Remembrance.txt
#  inflated: articles/Freddie_Hill.txt
#  inflated: articles/Matus_Lajcak.txt
#  inflated: articles/Barry_Gower.txt
#  inflated: articles/Death_of_Meraxes.txt
#  inflated: articles/Temmo.txt
#  inflated: articles/Tamzin_Merchant.txt
#  inflated: articles/Kraznys_mo_Nakloz.txt
#  inflated: articles/Josephine_Gillan.txt
#  inflated: articles/Elephant.txt
#  inflated: articles/Loyal_Night%27s_Watch_man_1.txt
#  inflated: articles/Will_Fortune.txt
#  inflated: articles/Griffin%27s_Roost.txt
#  inflated: articles/Needle.txt
#  inflated: articles/Barry_McGovern.txt
#  inflated: articles/Echiel.txt
#  inflated: articles/Alexander_Mileman.txt
#  inflated: articles/Hobb_the_Hewer.txt
#  inflated: articles/Ambush_at_the_harbor.txt
#  inflated: articles/Iron_Islands.txt
#  inflated: articles/Levan_Doran.txt
#  inflated: articles/Myraham.txt
#  inflated: articles/Protector_of_the_Seven_Kingdoms.txt
#  inflated: articles/Summerhall.txt
#  inflated: articles/Tully_bannerman.txt
#  inflated: articles/Lannister_messenger.txt
#  inflated: articles/Night%27s_Watch_archer.txt
#  inflated: articles/Clegane_(founder).txt
#  inflated: articles/The_Children.txt
#  inflated: articles/Godsway.txt
#  inflated: articles/Young_Bravo.txt
#  inflated: articles/Vanessa_Taylor.txt
#  inflated: articles/Great_Sept.txt
#  inflated: articles/Gallery:_Dragons.txt
#  inflated: articles/Lukas_Tomsik.txt
#  inflated: articles/HBO_Max.txt
#  inflated: articles/Game_of_Thrones_production_timeline.txt
#  inflated: articles/Lou_Wong.txt
#  inflated: articles/Riverrun.txt
#  inflated: articles/Eros_Vlahos.txt
#  inflated: articles/Gilwood_Hunter.txt
#  inflated: articles/Ashara_Dayne.txt
#  inflated: articles/John_Simm.txt
#  inflated: articles/Redwyne_Straits.txt
#  inflated: articles/Lannister.txt
#  inflated: articles/White_Walker_(Hardhome).txt
#  inflated: articles/The_known_world.txt
#  inflated: articles/Winter_Is_Coming_(motto).txt
#  inflated: articles/Matt_Shakman.txt
#  inflated: articles/Street_of_Sisters.txt
#  inflated: articles/Eduard_Hendija.txt
#  inflated: articles/Owen_Dickey.txt
#  inflated: articles/House_Humble.txt
#  inflated: articles/Assassination_of_Myrcella_Baratheon.txt
#  inflated: articles/Lady%27s_Lace.txt
#  inflated: articles/Roland_Crakehall.txt
#  inflated: articles/Emina_Muftic.txt
#  inflated: articles/Ornela.txt
#  inflated: articles/Filip_Kadlec.txt
#  inflated: articles/Rakharo.txt
#  inflated: articles/Aerys_I_Targaryen.txt
#  inflated: articles/Stark_messenger.txt
#  inflated: articles/Mark_Quigley.txt
#  inflated: articles/Koner.txt
#  inflated: articles/Macumber.txt
#  inflated: articles/Desertion.txt
#  inflated: articles/Bayasabhad.txt
#  inflated: articles/Rossart.txt
#  inflated: articles/Linda_Weal.txt
#  inflated: articles/Gary_Lightbody.txt
#  inflated: articles/Brendan_O%27Rourke.txt
#  inflated: articles/Bakkalon.txt
#  inflated: articles/Radoslav_Ignatov.txt
#  inflated: articles/Ken_Fletcher.txt
#  inflated: articles/Sumai.txt
#  inflated: articles/Brandon_Stark_(son_of_Rickard).txt
#  inflated: articles/Vhagar.txt
#  inflated: articles/Ray_Nicholas.txt
#  inflated: articles/George_Appleby.txt
#  inflated: articles/Prostitute.txt
#  inflated: articles/Littlefinger%27s_Brothel.txt
#  inflated: articles/Stark_guard_(The_Old_Gods_and_the_New).txt
#  inflated: articles/Jody_Halse.txt
#  inflated: articles/Logan_Bruce.txt
#  inflated: articles/Junade_Khan.txt
#  inflated: articles/Dornish_Marches.txt
#  inflated: articles/Michael_Slovis.txt
#  inflated: articles/Marianne_Frey.txt
#  inflated: articles/Fighting_pit_announcer.txt
#  inflated: articles/Giants.txt
#  inflated: articles/Mark_Slaughter.txt
#  inflated: articles/Slavko_Juraga.txt
#  inflated: articles/Hall_of_a_Thousand_Thrones.txt
#  inflated: articles/Jason_Oettle.txt
#  inflated: articles/Benedict_Blackmont.txt
#  inflated: articles/Melissa_Reid.txt
#  inflated: articles/Zack_Hemsey.txt
#  inflated: articles/Tanselle.txt
#  inflated: articles/City_Watch_of_King%27s_Landing.txt
#  inflated: articles/Moe_Dunford.txt
#  inflated: articles/Forbes_KB.txt
#  inflated: articles/Balon_Greyjoy.txt
#  inflated: articles/Paramour.txt
#  inflated: articles/Haggo.txt
#  inflated: articles/Max_Barber.txt
#  inflated: articles/Cheyk.txt
#  inflated: articles/Gwendoline_Christie.txt
#  inflated: articles/Sack_of_Mole%27s_Town.txt
#  inflated: articles/Ron_Donachie.txt
#  inflated: articles/Michelle_O%27Flaherty.txt
#  inflated: articles/Joe_Hewetson.txt
#  inflated: articles/Tourney_of_the_Hand.txt
#  inflated: articles/Brothel_customer.txt
#  inflated: articles/Karl_Davies.txt
#  inflated: articles/Sabrina_Bartlett.txt
#  inflated: articles/Siege_of_Great_Wyk.txt
#  inflated: articles/Rhalko.txt
#  inflated: articles/Sellswords.txt
#  inflated: articles/Lemon_Cakes.txt
#  inflated: articles/Edwina_Royce.txt
#  inflated: articles/Costumes.txt
#  inflated: articles/Winter.txt
#  inflated: articles/Mazor_Alexi.txt
#  inflated: articles/Dragonstone_(island).txt
#  inflated: articles/Ice_dragon.txt
#  inflated: articles/Shane_Steyn.txt
#  inflated: articles/Last_dragon.txt
#  inflated: articles/Dan_Griffiths.txt
#  inflated: articles/Rebecca_Benson.txt
#  inflated: articles/Sellsword_2.txt
#  inflated: articles/Ian_McShane.txt
#  inflated: articles/Rillwater_Crossing.txt
#  inflated: articles/Craster%27s_wife_2_(Walk_of_Punishment).txt
#  inflated: articles/Paul_Kennedy.txt
#  inflated: articles/Battle_of_Stone_Mill.txt
#  inflated: articles/Lord_of_Karhold.txt
#  inflated: articles/Rodrik_Flint.txt
#  inflated: articles/Stokeworth_(lord).txt
#  inflated: articles/Bezzaq.txt
#  inflated: articles/Master_of_Coin.txt
#  inflated: articles/Cleos_Frey.txt
#  inflated: articles/Dance_Over_Storm%27s_End.txt
#  inflated: articles/Whore_(Mother_of_Dragons).txt
#  inflated: articles/Execution_of_Eddard_Stark.txt
#  inflated: articles/Lands_of_Always_Winter.txt
#  inflated: articles/The_Lion_and_the_Rose.txt
#  inflated: articles/Rodrik_Forrester.txt
#  inflated: articles/Mustapha_Touki.txt
#  inflated: articles/Category_talk:Candidates_for_deletion.txt
#  inflated: articles/Aggo_(The_Red_Woman).txt
#  inflated: articles/Jogos_Nhai.txt
#  inflated: articles/Last_Hearth.txt
#  inflated: articles/Long_Table.txt
#  inflated: articles/Lord_of_the_Last_Hearth.txt
#  inflated: articles/Jaehaerys_Targaryen_(son_of_Aegon_II).txt
#  inflated: articles/Tortured_prisoner.txt
#  inflated: articles/Olyvar.txt
#  inflated: articles/Colin_Carnegie.txt
#  inflated: articles/House_Mullendore.txt
#  inflated: articles/Finn.txt
#  inflated: articles/Kai_Martin.txt
#  inflated: articles/Indira_Varma.txt
#  inflated: articles/Joel_Fry.txt
#  inflated: articles/King.txt
#  inflated: articles/Braavosi_Water_Dancer.txt
#  inflated: articles/Ghiscari_legion.txt
#  inflated: articles/Kevin_Keenan.txt
#  inflated: articles/Maxim_Royce.txt
#  inflated: articles/Tower_of_the_Hand.txt
#  inflated: articles/Ivan_Mica.txt
#  inflated: articles/Joel_Conlan.txt

# %%
import os
import urllib

titles = []
articles = []

i = 0

for filename in os.listdir('./articles'):
    if not filename[-3:] == 'txt':
        continue
    with open('articles/' + filename, 'rb') as f:
        title = urllib.parse.unquote(filename[:-4])
        title = title.replace('_', ' ')

        if (len(title) == 0) or (len(title.strip()) == 0):
            print("Empty title for", filename)
            continue

        titles.append(title)
        articles.append(f.read().decode('utf-8'))

    i += 1
    if(i % 500) == 0:
        print(' Processed {:,}'.format(i))

print('   DONE. \n')
print('There are {:,} articles.'.format(len(articles)))
# Out:
# Empty title for .txt
#  Processed 500
#  Processed 1,000
#  Processed 1,500
#  Processed 2,000
#  Processed 2,500
#  Processed 3,000
#  Processed 3,500
#  Processed 4,000
#  Processed 4,500
#    DONE.
#
# There are 4,882 articles.

# %%
passage_titles = []
passages = []

print('Splitting...')

for i in range(len(titles)):
    title = titles[i]
    article = articles[i]

    if len(article) == 0:
        print('Skipping empty article:', title)
        continue
    words = article.split()

    for i in range(0, len(words), 100):
        chunk_words = words[i:i+100]
        chunk = ' '.join(chunk_words)
        chunk = chunk.strip()

        if len(chunk) == 0:
            continue
        passage_titles.append(title)
        passages.append(chunk)

chunked_corpus = {'title': passage_titles, 'text': passages}
# Out:
# Splitting...

# %%
from transformers import DPRContextEncoderTokenizerFast

ctx_tokenizer = DPRContextEncoderTokenizerFast.from_pretrained("facebook/dpr-ctx_encoder-multiset-base")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizerFast'.

# %%
num_passags = len(chunked_corpus['title'])
print('Tokenizing {:,} passages for DPR...'.format(num_passags))

outputs = ctx_tokenizer(
    chunked_corpus['title'],
    chunked_corpus['text'],
    truncation=True,
    padding="longest",
    return_tensors='pt'
)

print('  DONE.')

input_ids = outputs['input_ids']
# Out:
# Tokenizing 43,151 passages for DPR...
#   DONE.

# %%
import torch

if torch.cuda.is_available():
    print("GPU available")
    device = torch.device("cuda")
else:
    print("No GPU available")
    device = torch.device("cpu")
# Out:
# GPU available

# %%
from transformers import DPRContextEncoder

ctx_encoder = DPRContextEncoder.from_pretrained("facebook/dpr-ctx_encoder-multiset-base")

ctx_encoder = ctx_encoder.to(device=device)
# Out:
# Some weights of the model checkpoint at facebook/dpr-ctx_encoder-multiset-base were not used when initializing DPRContextEncoder: ['ctx_encoder.bert_model.pooler.dense.bias', 'ctx_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRContextEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRContextEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import time
import datetime

def format_time(elapsed):
    elapsed_rounded = int(round(elapsed))
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import time
import math

torch.set_grad_enabled(False)

t0 = time.time()
step = 0
batch_size = 16

num_passages = input_ids.size()[0]
num_batches = math.ceil(num_passags/batch_size)

embeds_batches = []

print("Generating embeddings for {:,} passages...".format(num_passages))

for i in range(0, num_passages, batch_size):
    if step % 100 == 0 and not step == 0:
        elapsed = format_time(time.time() - t0)
        print("  Batch {:>5,} of {:>5,}.  Elapsed: {:}.".format(step, num_batches, elapsed))

    batch_ids = input_ids[i:i+16,:]
    batch_ids = batch_ids.to(device)

    outputs = ctx_encoder(
        batch_ids,
        return_dict=True
    )
    embeddings = outputs["pooler_output"]
    embeddings = embeddings.detach().cpu().numpy()

    embeds_batches.append(embeddings)
    step += 1

print("  Done.")
# Out:
# Generating embeddings for 43,151 passages...
#   Batch   100 of 2,697.  Elapsed: 0:00:31.
#   Batch   200 of 2,697.  Elapsed: 0:01:00.
#   Batch   300 of 2,697.  Elapsed: 0:01:31.
#   Batch   400 of 2,697.  Elapsed: 0:02:01.
#   Batch   500 of 2,697.  Elapsed: 0:02:33.
#   Batch   600 of 2,697.  Elapsed: 0:03:05.
#   Batch   700 of 2,697.  Elapsed: 0:03:37.
#   Batch   800 of 2,697.  Elapsed: 0:04:09.
#   Batch   900 of 2,697.  Elapsed: 0:04:42.
#   Batch 1,000 of 2,697.  Elapsed: 0:05:14.
#   Batch 1,100 of 2,697.  Elapsed: 0:05:47.
#   Batch 1,200 of 2,697.  Elapsed: 0:06:20.
#   Batch 1,300 of 2,697.  Elapsed: 0:06:53.
#   Batch 1,400 of 2,697.  Elapsed: 0:07:27.
#   Batch 1,500 of 2,697.  Elapsed: 0:08:00.
#   Batch 1,600 of 2,697.  Elapsed: 0:08:33.
#   Batch 1,700 of 2,697.  Elapsed: 0:09:07.
#   Batch 1,800 of 2,697.  Elapsed: 0:09:40.
#   Batch 1,900 of 2,697.  Elapsed: 0:10:13.
#   Batch 2,000 of 2,697.  Elapsed: 0:10:47.
#   Batch 2,100 of 2,697.  Elapsed: 0:11:20.
#   Batch 2,200 of 2,697.  Elapsed: 0:11:54.
#   Batch 2,300 of 2,697.  Elapsed: 0:12:27.
#   Batch 2,400 of 2,697.  Elapsed: 0:13:00.
#   Batch 2,500 of 2,697.  Elapsed: 0:13:34.
#   Batch 2,600 of 2,697.  Elapsed: 0:14:07.
#   Done.

# %%
import numpy as np

embeddings = np.concatenate(embeds_batches, axis=0)
print("Size of dataset embeddings:", embeddings.shape)
# Out:
# Size of dataset embeddings: (43151, 768)

# %%
import faiss

dim = 768

m = 128

index = faiss.IndexHNSWFlat(dim, m, faiss.METRIC_INNER_PRODUCT)

# %%
print("Building the FAISS Index")

t0 = time.time()

index.train(embeddings)
index.add(embeddings)

print(" DONE.")
# Out:
# Building the FAISS Index
#  DONE.

# %%
from transformers import DPRQuestionEncoder

q_encoder = DPRQuestionEncoder.from_pretrained("facebook/dpr-question_encoder-multiset-base")

q_encoder = q_encoder.to(device=device)
# Out:
# Some weights of the model checkpoint at facebook/dpr-question_encoder-multiset-base were not used when initializing DPRQuestionEncoder: ['question_encoder.bert_model.pooler.dense.bias', 'question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRQuestionEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRQuestionEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from transformers import DPRQuestionEncoderTokenizerFast

q_tokenizer = DPRQuestionEncoderTokenizerFast.from_pretrained("facebook/dpr-question_encoder-multiset-base")

# %%
input_ids = q_tokenizer.encode("Who is Arya's father?", return_tensors="pt")

input_ids = input_ids.to(device)

outputs = q_encoder(input_ids)

q_embed = outputs["pooler_output"]
q_embed = q_embed.cpu().numpy()

print("Query embedding:", q_embed.shape)
# Out:
# Query embedding: (1, 768)

# %%
D, I = index.search(q_embed, k=3)

print("Closest matching indeces:", I)
print("Inner Products:", D)
# Out:
# Closest matching indeces: [[14093 24289 24286]]
# Inner Products: [[81.73514  81.42131  80.646416]]

# %%
import textwrap

wrapper = textwrap.TextWrapper(width=80)

for i in I[0]:
  title = chunked_corpus['title'][i]
  passage = chunked_corpus['text'][i]

  print('Article Title:   ', title, '\n')
  print('Passage:')
  print(wrapper.fill(passage))

  print('')
# Out:
# Article Title:    Arya Stark and Gendry Baratheon
#
# Passage:
# later in life. However, Arya, given her tomboyish personality, disliked the
# expectations and restrictions of her gender, which caused her to frequently
# clash with her family, primarily with her mother and her sister Sansa. Gendry is
# an unacknowledged bastard son of King Robert Baratheon and a tavern wench. He
# lived in Flea Bottom. His mother died when he was young, and he grew up with no
# knowledge of his lineage or noble relations. He was not raised under the
# expectations of nobility, including arranged marriage. Gendry lived modestly,
# focusing mainly on his apprenticeship as a blacksmith under the mentorship of
#
# Article Title:    Arya Stark
#
# Passage:
# world end. == Contents == == Biography == === Background === Arya Stark is the
# youngest daughter and third child of Lady Catelyn and Lord Ned Stark. Arya was
# born and raised at Winterfell. She has an older sister, Sansa, an older brother
# Robb, two younger brothers Bran and Rickon Stark, and a "bastard half-brother"
# Jon Snow.[2] Arya rejects the notion that she must become a lady and marry for
# influence and power. Instead, she believes that she can forge her own destiny.
# She is fascinated by warfare and training in the use of arms, and is bored by
# embroidery
#
# Article Title:    Arya Stark
#
# Passage:
# === Portrayed by === Princess Arya Stark is the third child and second daughter
# of Lord Eddard Stark and his wife, Lady Catelyn Stark. She is the sister of the
# incumbent Westerosi monarchs, Sansa, Queen in the North, and Brandon, King of
# the Andals and the First Men. After narrowly escaping the persecution of House
# Stark by House Lannister, Arya is trained as a Faceless Man at the House of
# Black and White in Braavos, using her abilities to avenge her family. Upon her
# return to Westeros, she exacts retribution for the Red Wedding by exterminating
# the Frey male line.

# %%
 from datasets import Dataset
 import pandas as pd

 df = pd.DataFrame(chunked_corpus)
 dataset = Dataset.from_pandas(df)

 print(dataset)
# Out:
# Dataset({
#     features: ['title', 'text'],
#     num_rows: 43151
# })

# %%
embs = []

for i in range(embeddings.shape[0]):
  embs.append(embeddings[i, :])

# %%
dataset = dataset.add_column("embeddings", embs)

dataset
# Out:
# Dataset({
#     features: ['title', 'text', 'embeddings'],
#     num_rows: 43151
# })

# %%
index = faiss.IndexHNSWFlat(dim, m, faiss.METRIC_INNER_PRODUCT)
dataset.add_faiss_index(column="embeddings", index_name="embeddings", custom_index=index, faiss_verbose=True)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]
# Dataset({
#     features: ['title', 'text', 'embeddings'],
#     num_rows: 43151
# })

# %%
from transformers import RagRetriever

# %%
retriever = RagRetriever.from_pretrained(
    "facebook/rag-sequence-nq",
    use_dummy_dataset=False,
    indexed_dataset=dataset,
    index_name="embeddings"
)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.

# %%
print("hello")
# Out:
# hello

# %%
from transformers import RagTokenizer

tokenizer = RagTokenizer.from_pretrained(
    "facebook/rag-sequence-nq"
)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.

# %%
from transformers import RagSequenceForGeneration

model = RagSequenceForGeneration.from_pretrained(
    "facebook/rag-sequence-nq",
    retriever=retriever
)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/2.06G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/rag-sequence-nq were not used when initializing RagSequenceForGeneration: ['rag.question_encoder.question_encoder.bert_model.pooler.dense.weight', 'rag.question_encoder.question_encoder.bert_model.pooler.dense.bias']
# - This IS expected if you are initializing RagSequenceForGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RagSequenceForGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import time

t0 = time.time()

question = "Who is Arya's Father?"

input_ids = tokenizer.question_encoder(question, return_tensors="pt")["input_ids"]

# Give the question to RAG and have it generate an answer
generated = model.generate(input_ids)

generated_string = tokenizer.batch_decode(generated, skip_special_tokens=True)[0]

print("Q: " + question)
print("A: " + generated_string)

print('\nResponse took %.2f seconds' % (time.time()-t0))
# Out:
# Q: Who is Arya's Father?
# A:  lord eddard stark
#
# Response took 233.50 seconds

# %%
def ask_question(question):
  t0 = time.time()

  input_ids = tokenizer.question_encoder(question, return_tensors="pt")["input_ids"]
  generated = model.generate(input_ids)
  generated_string = tokenizer.batch_decode(generated, skip_special_tokens=True)[0]

  print("Q:" + question)
  print("A: '{:}".format(generated_string))

  print('\nResponse took %.2f seconds' % (time.time()-t0))
